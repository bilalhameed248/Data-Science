# %%
import pandas as pd

# %%
nba = pd.read_csv("nba.csv")

# %%
nba.head(5)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.sum()
# Out:
# C:\Users\Bilal\AppData\Local\Temp\ipykernel_3264\1629379923.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   nba.sum()
# Number    8.079000e+03
# Age       1.231100e+04
# Weight    1.012360e+05
# Salary    2.159837e+09
# dtype: float64

# %%
nba.isnull().any() # to find null value
# Out:
# Name        True
# Team        True
# Number      True
# Position    True
# Age         True
# Height      True
# Weight      True
# College     True
# Salary      True
# dtype: bool

# %%
nba.mean()
# Out:
# C:\Users\Bilal\AppData\Local\Temp\ipykernel_3264\3862783939.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   nba.mean()
# Number    1.767834e+01
# Age       2.693873e+01
# Weight    2.215230e+02
# Salary    4.842684e+06
# dtype: float64

# %%
# nba = nba.fillna(method='ffill') # to fill null value

# %%
nba = nba.fillna(nba.mean())
nba.head()
# Out:
# C:\Users\Bilal\AppData\Local\Temp\ipykernel_3264\361178804.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   nba = nba.fillna(nba.mean())
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College        Salary
# 0              Texas  7.730337e+06
# 1          Marquette  6.796117e+06
# 2  Boston University  4.842684e+06
# 3      Georgia State  1.148640e+06
# 4                NaN  5.000000e+06

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
sum1=0
for key in nba.index:
    sum1=sum1+nba["Number"][key]
print(sum1)
# Out:
# 8096.678336980306

# %%
nba.tail(3)
# Out:
#              Name       Team     Number Position        Age Height  \
# 455  Tibor Pleiss  Utah Jazz  21.000000        C  26.000000    7-3
# 456   Jeff Withey  Utah Jazz  24.000000        C  26.000000    7-0
# 457           NaN        NaN  17.678337      NaN  26.938731    NaN
#
#          Weight College        Salary
# 455  256.000000     NaN  2.900000e+06
# 456  231.000000  Kansas  9.472760e+05
# 457  221.522976     NaN  4.842684e+06

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
nba['Position'].value_counts()
# Out:
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: Position, dtype: int64

# %%
nba['Position'].fillna('PG', inplace=True)

# %%
nba.tail(3)
# Out:
#              Name       Team     Number Position        Age Height  \
# 455  Tibor Pleiss  Utah Jazz  21.000000        C  26.000000    7-3
# 456   Jeff Withey  Utah Jazz  24.000000        C  26.000000    7-0
# 457           NaN        NaN  17.678337       PG  26.938731    NaN
#
#          Weight College        Salary
# 455  256.000000     NaN  2.900000e+06
# 456  231.000000  Kansas  9.472760e+05
# 457  221.522976     NaN  4.842684e+06

# %%
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', 4842684.105381166],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, 17.678336980306344, ..., 221.52297592997812, nan,
#         4842684.105381166]], dtype=object)

# %%
nba.shape
# Out:
# (458, 9)

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
datatypes=nba.dtypes #a brand New Series will return

# %%
datatypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    458 non-null    float64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    458 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    458 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
# nba.get_dtype_counts()

# %% [markdown]
# ## Differences between Shared Methods

# %%
rev = pd.read_csv("revenue.csv", index_col="Date")
rev
# Out:
#          New York  Los Angeles  Miami
# Date
# 1/1/16        985          122    499
# 1/2/16        738          788    534
# 1/3/16         14           20    933
# 1/4/16        730          904    885
# 1/5/16        114           71    253
# 1/6/16        936          502    497
# 1/7/16        123          996    115
# 1/8/16        935          492    886
# 1/9/16        846          954    823
# 1/10/16        54          285    216

# %%
s=pd.Series([1,2,3])
s.sum()
# Out:
# 6

# %%
rev.sum()
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
rev.count()
# Out:
# New York       10
# Los Angeles    10
# Miami          10
# dtype: int64

# %%
rev['sum']=rev.sum(axis=1)

# %%
rev
# Out:
#          New York  Los Angeles  Miami   sum
# Date
# 1/1/16        985          122    499  1606
# 1/2/16        738          788    534  2060
# 1/3/16         14           20    933   967
# 1/4/16        730          904    885  2519
# 1/5/16        114           71    253   438
# 1/6/16        936          502    497  1935
# 1/7/16        123          996    115  1234
# 1/8/16        935          492    886  2313
# 1/9/16        846          954    823  2623
# 1/10/16        54          285    216   555

# %%
rev.sum(axis="columns")
# Out:
# Date
# 1/1/16     3212
# 1/2/16     4120
# 1/3/16     1934
# 1/4/16     5038
# 1/5/16      876
# 1/6/16     3870
# 1/7/16     2468
# 1/8/16     4626
# 1/9/16     5246
# 1/10/16    1110
# dtype: int64

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College        Salary
# 0              Texas  7.730337e+06
# 1          Marquette  6.796117e+06
# 2  Boston University  4.842684e+06
# 3      Georgia State  1.148640e+06
# 4                NaN  5.000000e+06

# %%
nba.Name # it just extract it as a series.
nba.Salary
# Out:
# 0      7.730337e+06
# 1      6.796117e+06
# 2      4.842684e+06
# 3      1.148640e+06
# 4      5.000000e+06
#            ...
# 453    2.433333e+06
# 454    9.000000e+05
# 455    2.900000e+06
# 456    9.472760e+05
# 457    4.842684e+06
# Name: Salary, Length: 458, dtype: float64

# %%
name=nba["Name"]     #More Acurate Methods
name
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %%
type(name)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Select Two or More Columns from a DataFrame

# %%
first_two=nba[["Name", "Team"]]
first_two
# Out:
#               Name            Team
# 0    Avery Bradley  Boston Celtics
# 1      Jae Crowder  Boston Celtics
# 2     John Holland  Boston Celtics
# 3      R.J. Hunter  Boston Celtics
# 4    Jonas Jerebko  Boston Celtics
# ..             ...             ...
# 453   Shelvin Mack       Utah Jazz
# 454      Raul Neto       Utah Jazz
# 455   Tibor Pleiss       Utah Jazz
# 456    Jeff Withey       Utah Jazz
# 457            NaN             NaN
#
# [458 rows x 2 columns]

# %%
first_two=nba[["Team", "Name"]]
first_two
# Out:
#                Team           Name
# 0    Boston Celtics  Avery Bradley
# 1    Boston Celtics    Jae Crowder
# 2    Boston Celtics   John Holland
# 3    Boston Celtics    R.J. Hunter
# 4    Boston Celtics  Jonas Jerebko
# ..              ...            ...
# 453       Utah Jazz   Shelvin Mack
# 454       Utah Jazz      Raul Neto
# 455       Utah Jazz   Tibor Pleiss
# 456       Utah Jazz    Jeff Withey
# 457             NaN            NaN
#
# [458 rows x 2 columns]

# %%
list_col=['Position', 'Age']
middle_two=nba[list_col]
middle_two
# Out:
#     Position        Age
# 0         PG  25.000000
# 1         SF  25.000000
# 2         SG  27.000000
# 3         SG  22.000000
# 4         PF  29.000000
# ..       ...        ...
# 453       PG  26.000000
# 454       PG  24.000000
# 455        C  26.000000
# 456        C  26.000000
# 457       PG  26.938731
#
# [458 rows x 2 columns]

# %%
first_two=nba[["Team", "Name"]]
first_two.head()
# Out:
#              Team           Name
# 0  Boston Celtics  Avery Bradley
# 1  Boston Celtics    Jae Crowder
# 2  Boston Celtics   John Holland
# 3  Boston Celtics    R.J. Hunter
# 4  Boston Celtics  Jonas Jerebko

# %%
select=["Number", "Position", "Age"]
select=nba[select]
select
# Out:
#         Number Position        Age
# 0     0.000000       PG  25.000000
# 1    99.000000       SF  25.000000
# 2    30.000000       SG  27.000000
# 3    28.000000       SG  22.000000
# 4     8.000000       PF  29.000000
# ..         ...      ...        ...
# 453   8.000000       PG  26.000000
# 454  25.000000       PG  24.000000
# 455  21.000000        C  26.000000
# 456  24.000000        C  26.000000
# 457  17.678337       PG  26.938731
#
# [458 rows x 3 columns]

# %% [markdown]
# ## Add New Column to DataFrame

# %%
nba["Sport"]="Basketball"

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College        Salary       Sport
# 0              Texas  7.730337e+06  Basketball
# 1          Marquette  6.796117e+06  Basketball
# 2  Boston University  4.842684e+06  Basketball
# 3      Georgia State  1.148640e+06  Basketball
# 4                NaN  5.000000e+06  Basketball

# %%
nba.insert(3, column="Sport1", value="Basketball")

# %%
nba.head(3)
# Out:
#             Name            Team  Number      Sport1 Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
#
#    Weight            College        Salary       Sport
# 0   180.0              Texas  7.730337e+06  Basketball
# 1   235.0          Marquette  6.796117e+06  Basketball
# 2   205.0  Boston University  4.842684e+06  Basketball

# %%
nba.insert(7, column="League", value="National Basketball association")
nba.head()
# Out:
#             Name            Team  Number      Sport1 Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
# 3    R.J. Hunter  Boston Celtics    28.0  Basketball       SG  22.0    6-5
# 4  Jonas Jerebko  Boston Celtics     8.0  Basketball       PF  29.0   6-10
#
#                             League  Weight            College        Salary  \
# 0  National Basketball association   180.0              Texas  7.730337e+06
# 1  National Basketball association   235.0          Marquette  6.796117e+06
# 2  National Basketball association   205.0  Boston University  4.842684e+06
# 3  National Basketball association   185.0      Georgia State  1.148640e+06
# 4  National Basketball association   231.0                NaN  5.000000e+06
#
#         Sport
# 0  Basketball
# 1  Basketball
# ...

# %% [markdown]
# ##  Broadcasting Operations

# %%
nba["Age"]
# Out:
# 0      25.000000
# 1      25.000000
# 2      27.000000
# 3      22.000000
# 4      29.000000
#          ...
# 453    26.000000
# 454    24.000000
# 455    26.000000
# 456    26.000000
# 457    26.938731
# Name: Age, Length: 458, dtype: float64

# %%
nba["Age"].add(5)
nba["Age"] + 6 #Work same as above
# Out:
# 0      31.000000
# 1      31.000000
# 2      33.000000
# 3      28.000000
# 4      35.000000
#          ...
# 453    32.000000
# 454    30.000000
# 455    32.000000
# 456    32.000000
# 457    32.938731
# Name: Age, Length: 458, dtype: float64

# %%
nba["Age"].sub(5)
# Out:
# 0      20.000000
# 1      20.000000
# 2      22.000000
# 3      17.000000
# 4      24.000000
#          ...
# 453    21.000000
# 454    19.000000
# 455    21.000000
# 456    21.000000
# 457    21.938731
# Name: Age, Length: 458, dtype: float64

# %%
nba["Weight"].mul(0.4535) #*
# Out:
# 0       81.63000
# 1      106.57250
# 2       92.96750
# 3       83.89750
# 4      104.75850
#          ...
# 453     92.06050
# 454     81.17650
# 455    116.09600
# 456    104.75850
# 457    100.46067
# Name: Weight, Length: 458, dtype: float64

# %%
nba["Weight in Kilogram"]=nba["Weight"].mul(0.4535)

# %%
nba.head()
# Out:
#             Name            Team  Number      Sport1 Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
# 3    R.J. Hunter  Boston Celtics    28.0  Basketball       SG  22.0    6-5
# 4  Jonas Jerebko  Boston Celtics     8.0  Basketball       PF  29.0   6-10
#
#                             League  Weight            College        Salary  \
# 0  National Basketball association   180.0              Texas  7.730337e+06
# 1  National Basketball association   235.0          Marquette  6.796117e+06
# 2  National Basketball association   205.0  Boston University  4.842684e+06
# 3  National Basketball association   185.0      Georgia State  1.148640e+06
# 4  National Basketball association   231.0                NaN  5.000000e+06
#
#         Sport  Weight in Kilogram
# ...

# %%
nba["Salary"].div(1000000)
nba["Salary in Million"]=nba["Salary"] / (1000000)

# %% [markdown]
# ## A Review of the .value_counts() Method

# %%
nba["Team"].value_counts()
# Out:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# Boston Celtics            15
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Dallas Mavericks          15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Utah Jazz                 15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: Team, dtype: int64

# %%
nba["Position"].value_counts()
# Out:
# SG    102
# PF    100
# PG     93
# SF     85
# C      78
# Name: Position, dtype: int64

# %% [markdown]
# ## Drop Rows with Null Values

# %%
nba.dropna()
# Out:
#               Name            Team  Number      Sport1 Position   Age Height  \
# 0    Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1      Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 2     John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
# 3      R.J. Hunter  Boston Celtics    28.0  Basketball       SG  22.0    6-5
# 6    Jordan Mickey  Boston Celtics    55.0  Basketball       PF  21.0    6-8
# ..             ...             ...     ...         ...      ...   ...    ...
# 449    Rodney Hood       Utah Jazz     5.0  Basketball       SG  23.0    6-8
# 451  Chris Johnson       Utah Jazz    23.0  Basketball       SF  26.0    6-6
# 452     Trey Lyles       Utah Jazz    41.0  Basketball       PF  20.0   6-10
# 453   Shelvin Mack       Utah Jazz     8.0  Basketball       PG  26.0    6-3
# 456    Jeff Withey       Utah Jazz    24.0  Basketball        C  26.0    7-0
#
# ...

# %%
nba.dropna(how="all", inplace=True)

# %%
nba.tail()
# Out:
#              Name       Team     Number      Sport1 Position        Age  \
# 453  Shelvin Mack  Utah Jazz   8.000000  Basketball       PG  26.000000
# 454     Raul Neto  Utah Jazz  25.000000  Basketball       PG  24.000000
# 455  Tibor Pleiss  Utah Jazz  21.000000  Basketball        C  26.000000
# 456   Jeff Withey  Utah Jazz  24.000000  Basketball        C  26.000000
# 457           NaN        NaN  17.678337  Basketball       PG  26.938731
#
#     Height                           League      Weight College        Salary  \
# 453    6-3  National Basketball association  203.000000  Butler  2.433333e+06
# 454    6-1  National Basketball association  179.000000     NaN  9.000000e+05
# 455    7-3  National Basketball association  256.000000     NaN  2.900000e+06
# 456    7-0  National Basketball association  231.000000  Kansas  9.472760e+05
# 457    NaN  National Basketball association  221.522976     NaN  4.842684e+06
#
#           Sport  Weight in Kilogram  Salary in Million
# ...

# %%
nba.dropna(axis=1)
# Out:
#         Number      Sport1 Position        Age  \
# 0     0.000000  Basketball       PG  25.000000
# 1    99.000000  Basketball       SF  25.000000
# 2    30.000000  Basketball       SG  27.000000
# 3    28.000000  Basketball       SG  22.000000
# 4     8.000000  Basketball       PF  29.000000
# ..         ...         ...      ...        ...
# 453   8.000000  Basketball       PG  26.000000
# 454  25.000000  Basketball       PG  24.000000
# 455  21.000000  Basketball        C  26.000000
# 456  24.000000  Basketball        C  26.000000
# 457  17.678337  Basketball       PG  26.938731
#
#                               League      Weight        Salary       Sport  \
# 0    National Basketball association  180.000000  7.730337e+06  Basketball
# 1    National Basketball association  235.000000  6.796117e+06  Basketball
# 2    National Basketball association  205.000000  4.842684e+06  Basketball
# 3    National Basketball association  185.000000  1.148640e+06  Basketball
# ...

# %%
nba.dropna(subset=["Salary"])
# Out:
#               Name            Team     Number      Sport1 Position        Age  \
# 0    Avery Bradley  Boston Celtics   0.000000  Basketball       PG  25.000000
# 1      Jae Crowder  Boston Celtics  99.000000  Basketball       SF  25.000000
# 2     John Holland  Boston Celtics  30.000000  Basketball       SG  27.000000
# 3      R.J. Hunter  Boston Celtics  28.000000  Basketball       SG  22.000000
# 4    Jonas Jerebko  Boston Celtics   8.000000  Basketball       PF  29.000000
# ..             ...             ...        ...         ...      ...        ...
# 453   Shelvin Mack       Utah Jazz   8.000000  Basketball       PG  26.000000
# 454      Raul Neto       Utah Jazz  25.000000  Basketball       PG  24.000000
# 455   Tibor Pleiss       Utah Jazz  21.000000  Basketball        C  26.000000
# 456    Jeff Withey       Utah Jazz  24.000000  Basketball        C  26.000000
# 457            NaN             NaN  17.678337  Basketball       PG  26.938731
#
# ...

# %% [markdown]
# ## Fill in Null Values with the .fillna() Method

# %%
 nba.fillna(1)
# Out:
#               Name            Team     Number      Sport1 Position        Age  \
# 0    Avery Bradley  Boston Celtics   0.000000  Basketball       PG  25.000000
# 1      Jae Crowder  Boston Celtics  99.000000  Basketball       SF  25.000000
# 2     John Holland  Boston Celtics  30.000000  Basketball       SG  27.000000
# 3      R.J. Hunter  Boston Celtics  28.000000  Basketball       SG  22.000000
# 4    Jonas Jerebko  Boston Celtics   8.000000  Basketball       PF  29.000000
# ..             ...             ...        ...         ...      ...        ...
# 453   Shelvin Mack       Utah Jazz   8.000000  Basketball       PG  26.000000
# 454      Raul Neto       Utah Jazz  25.000000  Basketball       PG  24.000000
# 455   Tibor Pleiss       Utah Jazz  21.000000  Basketball        C  26.000000
# 456    Jeff Withey       Utah Jazz  24.000000  Basketball        C  26.000000
# 457              1               1  17.678337  Basketball       PG  26.938731
#
# ...

# %%
nba.head()
# Out:
#             Name            Team  Number      Sport1 Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
# 3    R.J. Hunter  Boston Celtics    28.0  Basketball       SG  22.0    6-5
# 4  Jonas Jerebko  Boston Celtics     8.0  Basketball       PF  29.0   6-10
#
#                             League  Weight            College        Salary  \
# 0  National Basketball association   180.0              Texas  7.730337e+06
# 1  National Basketball association   235.0          Marquette  6.796117e+06
# 2  National Basketball association   205.0  Boston University  4.842684e+06
# 3  National Basketball association   185.0      Georgia State  1.148640e+06
# 4  National Basketball association   231.0                NaN  5.000000e+06
#
#         Sport  Weight in Kilogram  Salary in Million
# ...

# %%
nba["Salary"].fillna(0, inplace=True)

# %%
nba["College"].fillna("PCIT", inplace=True)

# %%
nba.tail()
# Out:
#              Name       Team     Number      Sport1 Position        Age  \
# 453  Shelvin Mack  Utah Jazz   8.000000  Basketball       PG  26.000000
# 454     Raul Neto  Utah Jazz  25.000000  Basketball       PG  24.000000
# 455  Tibor Pleiss  Utah Jazz  21.000000  Basketball        C  26.000000
# 456   Jeff Withey  Utah Jazz  24.000000  Basketball        C  26.000000
# 457           NaN        NaN  17.678337  Basketball       PG  26.938731
#
#     Height                           League      Weight College        Salary  \
# 453    6-3  National Basketball association  203.000000  Butler  2.433333e+06
# 454    6-1  National Basketball association  179.000000    PCIT  9.000000e+05
# 455    7-3  National Basketball association  256.000000    PCIT  2.900000e+06
# 456    7-0  National Basketball association  231.000000  Kansas  9.472760e+05
# 457    NaN  National Basketball association  221.522976    PCIT  4.842684e+06
#
#           Sport  Weight in Kilogram  Salary in Million
# ...

# %% [markdown]
# ## The .astype() Method

# %%
nba=pd.read_csv("nba.csv").dropna(how="all")
nba["Salary"].fillna(0, inplace=True)
nba["College"].fillna("MCS", inplace=True)
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba.dtypes
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   457 non-null    object
#  8   Salary    457 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 35.7+ KB

# %%
nba["Salary"]=nba["Salary"].astype("int")

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0
# 3      Georgia State  1148640
# 4                MCS  5000000

# %%
nba["Age"]=nba["Age"].astype("int")

# %%
nba.head()
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG   25    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF   25    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG   27    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG   22    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF   29   6-10   231.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0
# 3      Georgia State  1148640
# 4                MCS  5000000

# %%
nba["Position"].nunique()
# Out:
# 5

# %%
nba["Position"]=nba["Position"].astype("category")

# %%
nba
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG   25    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF   25    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG   27    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG   22    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF   29   6-10   231.0
# ..             ...             ...     ...      ...  ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF   20   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG   26    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG   24    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C   26    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C   26    7-0   231.0
#
#                College   Salary
# 0                Texas  7730337
# 1            Marquette  6796117
# ...

# %%
nba["Team"].nunique()
# Out:
# 30

# %%
nba["Team"].value_counts()
# Out:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# Boston Celtics            15
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Dallas Mavericks          15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Utah Jazz                 15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: Team, dtype: int64

# %%
nba["Team"]=nba["Team"].astype("category")

# %% [markdown]
# ## Sort a DataFrame with the .sort_values() Method, Part I

# %%
nba.sort_values("Name", ascending=False)
# nba.sort_values("Name")
# Out:
#                 Name                    Team  Number Position  Age Height  \
# 237    Zaza Pachulia        Dallas Mavericks    27.0        C   32   6-11
# 271    Zach Randolph       Memphis Grizzlies    50.0       PF   34    6-9
# 402      Zach LaVine  Minnesota Timberwolves     8.0       PG   21    6-5
# 270   Xavier Munford       Memphis Grizzlies    14.0       PG   24    6-3
# 386  Wilson Chandler          Denver Nuggets    21.0       SF   29    6-8
# ..               ...                     ...     ...      ...  ...    ...
# 312       Al Horford           Atlanta Hawks    15.0        C   30   6-10
# 404    Adreian Payne  Minnesota Timberwolves    33.0       PF   25   6-10
# 328   Aaron Harrison       Charlotte Hornets     9.0       SG   21    6-6
# 356     Aaron Gordon           Orlando Magic     0.0       PF   20    6-9
# 152     Aaron Brooks           Chicago Bulls     0.0       PG   31    6-0
#
#      Weight         College    Salary
# 237   275.0             MCS   5200000
# ...

# %%
nba.sort_values("Age", ascending=True , inplace=True)

# %%
nba.head()
# Out:
#                    Name                    Team  Number Position  Age Height  \
# 226       Rashad Vaughn         Milwaukee Bucks    20.0       SG   19    6-6
# 122        Devin Booker            Phoenix Suns     1.0       SG   19    6-6
# 40   Kristaps Porzingis         New York Knicks     6.0       PF   20    7-3
# 401          Tyus Jones  Minnesota Timberwolves     1.0       PG   20    6-2
# 427     Cliff Alexander  Portland Trail Blazers    34.0       PF   20    6-8
#
#      Weight   College   Salary
# 226   202.0      UNLV  1733040
# 122   206.0  Kentucky  2127840
# 40    240.0       MCS  4131720
# 401   195.0      Duke  1282080
# 427   240.0    Kansas   525093

# %%
nba.tail()
# Out:
#                Name                    Team  Number Position  Age Height  \
# 261    Vince Carter       Memphis Grizzlies    15.0       SG   39    6-6
# 102  Pablo Prigioni    Los Angeles Clippers     9.0       PG   39    6-3
# 298      Tim Duncan       San Antonio Spurs    21.0        C   40   6-11
# 400   Kevin Garnett  Minnesota Timberwolves    21.0       PF   40   6-11
# 304    Andre Miller       San Antonio Spurs    24.0       PG   40    6-3
#
#      Weight         College   Salary
# 261   220.0  North Carolina  4088019
# 102   185.0             MCS   947726
# 298   250.0     Wake Forest  5250000
# 400   240.0             MCS  8500000
# 304   200.0            Utah   250750

# %%
nba.sort_values("Salary", ascending=True , inplace=True)

# %%
nba.sort_values("Salary", ascending=False , inplace=True, na_position="first")

# %%
nba.tail(30)
# Out:
#                        Name                    Team  Number Position  Age  \
# 304            Andre Miller       San Antonio Spurs    24.0       PG   40
# 73           Jason Thompson         Toronto Raptors     1.0       PF   29
# 420           Nazr Mohammed   Oklahoma City Thunder    13.0        C   38
# 203               Ty Lawson          Indiana Pacers    10.0       PG   28
# 123          Chase Budinger            Phoenix Suns    10.0       SF   28
# 303            Kevin Martin       San Antonio Spurs    23.0       SG   33
# 381         Marcus Thornton      Washington Wizards    15.0       SF   29
# 248        Andrew Goudelock         Houston Rockets     0.0       PG   27
# 326         Jorge Gutierrez       Charlotte Hornets    12.0       PG   27
# 282      Bryce Dejean-Jones    New Orleans Pelicans    31.0       SG   23
# 45              Tony Wroten         New York Knicks     5.0       SG   23
# 21          Sean Kilpatrick           Brooklyn Nets     6.0       SG   26
# ...

# %% [markdown]
# ## Sort a DataFrame with the .sort_values() Method, Part II

# %%
nba.sort_values(["Team", "Name"]).head(50)
# Out:
#                         Name               Team  Number Position  Age Height  \
# 312               Al Horford      Atlanta Hawks    15.0        C   30   6-10
# 318          Dennis Schroder      Atlanta Hawks    17.0       PG   22    6-1
# 323              Jeff Teague      Atlanta Hawks     0.0       PG   27    6-2
# 309            Kent Bazemore      Atlanta Hawks    24.0       SF   26    6-5
# 311             Kirk Hinrich      Atlanta Hawks    12.0       SG   35    6-4
# 313           Kris Humphries      Atlanta Hawks    43.0       PF   31    6-9
# 314              Kyle Korver      Atlanta Hawks    26.0       SG   35    6-7
# 317          Lamar Patterson      Atlanta Hawks    13.0       SG   24    6-5
# 316             Mike Muscala      Atlanta Hawks    31.0       PF   24   6-11
# 319               Mike Scott      Atlanta Hawks    32.0       PF   27    6-8
# 315             Paul Millsap      Atlanta Hawks     4.0       PF   31    6-8
# ...

# %%
nba.sort_values(["Team", "Name"], ascending=[True, False]).head(50)
# Out:
#                         Name               Team  Number Position  Age Height  \
# 322           Walter Tavares      Atlanta Hawks    22.0        C   24    7-3
# 310         Tim Hardaway Jr.      Atlanta Hawks    10.0       SG   24    6-6
# 321           Tiago Splitter      Atlanta Hawks    11.0        C   31   6-11
# 320          Thabo Sefolosha      Atlanta Hawks    25.0       SF   32    6-7
# 315             Paul Millsap      Atlanta Hawks     4.0       PF   31    6-8
# 319               Mike Scott      Atlanta Hawks    32.0       PF   27    6-8
# 316             Mike Muscala      Atlanta Hawks    31.0       PF   24   6-11
# 317          Lamar Patterson      Atlanta Hawks    13.0       SG   24    6-5
# 314              Kyle Korver      Atlanta Hawks    26.0       SG   35    6-7
# 313           Kris Humphries      Atlanta Hawks    43.0       PF   31    6-9
# 311             Kirk Hinrich      Atlanta Hawks    12.0       SG   35    6-4
# ...

# %%
nba.sort_values(["Team", "Salary"], ascending=[True, False]).head(50)
# Out:
#                         Name               Team  Number Position  Age Height  \
# 315             Paul Millsap      Atlanta Hawks     4.0       PF   31    6-8
# 312               Al Horford      Atlanta Hawks    15.0        C   30   6-10
# 321           Tiago Splitter      Atlanta Hawks    11.0        C   31   6-11
# 323              Jeff Teague      Atlanta Hawks     0.0       PG   27    6-2
# 314              Kyle Korver      Atlanta Hawks    26.0       SG   35    6-7
# 320          Thabo Sefolosha      Atlanta Hawks    25.0       SF   32    6-7
# 319               Mike Scott      Atlanta Hawks    32.0       PF   27    6-8
# 311             Kirk Hinrich      Atlanta Hawks    12.0       SG   35    6-4
# 309            Kent Bazemore      Atlanta Hawks    24.0       SF   26    6-5
# 318          Dennis Schroder      Atlanta Hawks    17.0       PG   22    6-1
# 310         Tim Hardaway Jr.      Atlanta Hawks    10.0       SG   24    6-6
# ...

# %% [markdown]
# ## Sort DataFrame with the .sort_index() Method

# %%
nba.sort_values(["Number", "Salary", "Name"], inplace=True)
nba.tail(10)
# Out:
#                     Name                    Team  Number Position  Age Height  \
# 6          Jordan Mickey          Boston Celtics    55.0       PF   21    6-8
# 75          Delon Wright         Toronto Raptors    55.0       PG   24    6-5
# 359     Brandon Jennings           Orlando Magic    55.0       PG   26    6-1
# 222  Johnny O'Bryant III         Milwaukee Bucks    77.0       PF   23    6-9
# 391    Joffrey Lauvergne          Denver Nuggets    77.0        C   24   6-11
# 398      Nemanja Bjelica  Minnesota Timberwolves    88.0       PF   28   6-10
# 372          Drew Gooden      Washington Wizards    90.0       PF   34   6-10
# 5           Amir Johnson          Boston Celtics    90.0       PF   29    6-9
# 68        Lucas Nogueira         Toronto Raptors    92.0        C   23    7-0
# 1            Jae Crowder          Boston Celtics    99.0       SF   25    6-6
#
#      Weight    College    Salary
# 6     235.0        LSU   1170960
# 75    190.0       Utah   1509360
# ...

# %%
nba.sort_index()
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG   25    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF   25    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG   27    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG   22    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF   29   6-10   231.0
# ..             ...             ...     ...      ...  ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF   20   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG   26    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG   24    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C   26    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C   26    7-0   231.0
#
#                College   Salary
# 0                Texas  7730337
# 1            Marquette  6796117
# ...

# %% [markdown]
# ## Rank Values with the .rank() Method

# %%
nba.dropna(how="all")
nba["Salary"]=nba["Salary"].fillna(0).astype("int")
nba.head(10)
# Out:
#                  Name                  Team  Number Position  Age Height  \
# 291   Orlando Johnson  New Orleans Pelicans     0.0       SG   27    6-5
# 248  Andrew Goudelock       Houston Rockets     0.0       PG   27    6-3
# 347   Josh Richardson            Miami Heat     0.0       SG   22    6-6
# 266    JaMychal Green     Memphis Grizzlies     0.0       PF   25    6-9
# 47      Isaiah Canaan    Philadelphia 76ers     0.0       PG   25    6-0
# 22       Shane Larkin         Brooklyn Nets     0.0       PG   23   5-11
# 152      Aaron Brooks         Chicago Bulls     0.0       PG   31    6-0
# 383    Darrell Arthur        Denver Nuggets     0.0       PF   28    6-9
# 393   Emmanuel Mudiay        Denver Nuggets     0.0       PG   20    6-5
# 188    Andre Drummond       Detroit Pistons     0.0        C   22   6-11
#
#      Weight           College   Salary
# 291   220.0  UC Santa Barbara    55722
# 248   200.0        Charleston   200600
# 347   200.0         Tennessee   525093
# ...

# %%
nba["Salary"].rank()
# Out:
# 291     13.5
# 248     24.0
# 347     43.0
# 266     64.5
# 47      91.0
#        ...
# 398    281.0
# 372    260.0
# 5      401.0
# 68     187.5
# 1      348.0
# Name: Salary, Length: 457, dtype: float64

# %%
nba["Salary Rank"]=nba["Salary"].rank(ascending=False).astype("int")
nba.head(10)
# Out:
#                  Name                  Team  Number Position  Age Height  \
# 291   Orlando Johnson  New Orleans Pelicans     0.0       SG   27    6-5
# 248  Andrew Goudelock       Houston Rockets     0.0       PG   27    6-3
# 347   Josh Richardson            Miami Heat     0.0       SG   22    6-6
# 266    JaMychal Green     Memphis Grizzlies     0.0       PF   25    6-9
# 47      Isaiah Canaan    Philadelphia 76ers     0.0       PG   25    6-0
# 22       Shane Larkin         Brooklyn Nets     0.0       PG   23   5-11
# 152      Aaron Brooks         Chicago Bulls     0.0       PG   31    6-0
# 383    Darrell Arthur        Denver Nuggets     0.0       PF   28    6-9
# 393   Emmanuel Mudiay        Denver Nuggets     0.0       PG   20    6-5
# 188    Andre Drummond       Detroit Pistons     0.0        C   22   6-11
#
#      Weight           College   Salary  Salary Rank
# 291   220.0  UC Santa Barbara    55722          444
# 248   200.0        Charleston   200600          434
# ...

# %%
nba.sort_values(["Salary"], ascending=False).head(50)
# Out:
#                   Name                    Team  Number Position  Age Height  \
# 109        Kobe Bryant      Los Angeles Lakers    24.0       SF   37    6-6
# 169       LeBron James     Cleveland Cavaliers    23.0       SF   31    6-8
# 33     Carmelo Anthony         New York Knicks     7.0       SF   32    6-8
# 251      Dwight Howard         Houston Rockets    12.0        C   30   6-11
# 339         Chris Bosh              Miami Heat     1.0       PF   32   6-11
# 100         Chris Paul    Los Angeles Clippers     3.0       PG   31    6-0
# 414       Kevin Durant   Oklahoma City Thunder    35.0       SF   27    6-9
# 164       Derrick Rose           Chicago Bulls     1.0       PG   27    6-3
# 349        Dwyane Wade              Miami Heat     3.0       SG   34    6-4
# 23         Brook Lopez           Brooklyn Nets    11.0        C   28    7-0
# 294  LaMarcus Aldridge       San Antonio Spurs    12.0       PF   30   6-11
# ...
