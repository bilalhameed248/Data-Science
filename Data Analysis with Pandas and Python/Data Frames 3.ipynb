# %%
import pandas as pd

# %%
bond=pd.read_csv("jamesbond.csv")

# %%
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %% [markdown]
# ##  The .set_index() and .reset_index() Methods

# %%
bond.set_index("Film" , inplace=True)
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
bond.reset_index(inplace = True)
bond
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %% [markdown]
# ## Retrieve Rows by Index Label with .loc[]

# %%
bond.sort_index(inplace=True)

# %%
bond
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
bond.reset_index(inplace = True)
bond.loc[6]
# Out:
# index                                              6
# Film                 On Her Majesty's Secret Service
# Year                                            1969
# Actor                                 George Lazenby
# Director                               Peter R. Hunt
# Box Office                                     291.5
# Budget                                          37.3
# Bond Actor Salary                                0.6
# Name: 6, dtype: object

# %%
# bond.loc["xyz"]

# %%
bond.set_index("Film" , inplace=True)
bond.loc["Casino Royale"]
# Out:
#                index  Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale      4  1967   David Niven       Ken Hughes       315.0    85.0
# Casino Royale     22  2006  Daniel Craig  Martin Campbell       581.5   145.3
#
#                Bond Actor Salary
# Film
# Casino Royale                NaN
# Casino Royale                3.3

# %%
bond.loc["The Living Daylights":"Skyfall"]
# Out:
#                          index  Year           Actor            Director  \
# Film
# The Living Daylights        16  1987  Timothy Dalton           John Glen
# Licence to Kill             17  1989  Timothy Dalton           John Glen
# GoldenEye                   18  1995  Pierce Brosnan     Martin Campbell
# Tomorrow Never Dies         19  1997  Pierce Brosnan  Roger Spottiswoode
# The World Is Not Enough     20  1999  Pierce Brosnan       Michael Apted
# Die Another Day             21  2002  Pierce Brosnan        Lee Tamahori
# Casino Royale               22  2006    Daniel Craig     Martin Campbell
# Quantum of Solace           23  2008    Daniel Craig        Marc Forster
# Skyfall                     24  2012    Daniel Craig          Sam Mendes
#
#                          Box Office  Budget  Bond Actor Salary
# Film
# The Living Daylights          313.5    68.8                5.2
# Licence to Kill               250.9    56.7                7.9
# ...

# %%
bond.loc["Skyfall":]
# Out:
#          index  Year         Actor    Director  Box Office  Budget  \
# Film
# Skyfall     24  2012  Daniel Craig  Sam Mendes       943.5   170.2
# Spectre     25  2015  Daniel Craig  Sam Mendes       726.7   206.3
#
#          Bond Actor Salary
# Film
# Skyfall               14.5
# Spectre                NaN

# %%
bond.loc[["Thunderball", "The Living Daylights"]]
# Out:
#                       index  Year           Actor       Director  Box Office  \
# Film
# Thunderball               3  1965    Sean Connery  Terence Young       848.1
# The Living Daylights     16  1987  Timothy Dalton      John Glen       313.5
#
#                       Budget  Bond Actor Salary
# Film
# Thunderball             41.9                4.7
# The Living Daylights    68.8                5.2

# %%
bond.loc[["Thunderball", "The Living Daylights", "Tomorrow Never Dies"]]
# Out:
#                       index  Year           Actor            Director  \
# Film
# Thunderball               3  1965    Sean Connery       Terence Young
# The Living Daylights     16  1987  Timothy Dalton           John Glen
# Tomorrow Never Dies      19  1997  Pierce Brosnan  Roger Spottiswoode
#
#                       Box Office  Budget  Bond Actor Salary
# Film
# Thunderball                848.1    41.9                4.7
# The Living Daylights       313.5    68.8                5.2
# Tomorrow Never Dies        463.2   133.9               10.0

# %%
"xyz" in bond.index
# Out:
# False

# %%
bond.reset_index(inplace = True)
bond.loc[0:5]
# Out:
#                     Film  index  Year         Actor       Director  \
# 0                 Dr. No      0  1962  Sean Connery  Terence Young
# 1  From Russia with Love      1  1963  Sean Connery  Terence Young
# 2             Goldfinger      2  1964  Sean Connery   Guy Hamilton
# 3            Thunderball      3  1965  Sean Connery  Terence Young
# 4          Casino Royale      4  1967   David Niven     Ken Hughes
# 5    You Only Live Twice      5  1967  Sean Connery  Lewis Gilbert
#
#    Box Office  Budget  Bond Actor Salary
# 0       448.8     7.0                0.6
# 1       543.8    12.6                1.6
# 2       820.4    18.6                3.2
# 3       848.1    41.9                4.7
# 4       315.0    85.0                NaN
# 5       514.2    59.9                4.4

# %% [markdown]
# ## Retrieve Rows by Index Position with .iloc[]

# %%
bond.loc[15]
bond.iloc[14]
# Out:
# Film                   Octopussy
# index                         14
# Year                        1983
# Actor                Roger Moore
# Director               John Glen
# Box Office                 373.8
# Budget                      53.9
# Bond Actor Salary            7.8
# Name: 14, dtype: object

# %%
bond.iloc[15:20]
# Out:
#                     Film  index  Year           Actor            Director  \
# 15      A View to a Kill     15  1985     Roger Moore           John Glen
# 16  The Living Daylights     16  1987  Timothy Dalton           John Glen
# 17       Licence to Kill     17  1989  Timothy Dalton           John Glen
# 18             GoldenEye     18  1995  Pierce Brosnan     Martin Campbell
# 19   Tomorrow Never Dies     19  1997  Pierce Brosnan  Roger Spottiswoode
#
#     Box Office  Budget  Bond Actor Salary
# 15       275.2    54.5                9.1
# 16       313.5    68.8                5.2
# 17       250.9    56.7                7.9
# 18       518.5    76.9                5.1
# 19       463.2   133.9               10.0

# %%
bond.iloc[[15,20]]
# Out:
#                        Film  index  Year           Actor       Director  \
# 15         A View to a Kill     15  1985     Roger Moore      John Glen
# 20  The World Is Not Enough     20  1999  Pierce Brosnan  Michael Apted
#
#     Box Office  Budget  Bond Actor Salary
# 15       275.2    54.5                9.1
# 20       439.5   158.3               13.5

# %%
bond=pd.read_csv("jamesbond.csv")
bond.set_index("Film" , inplace=True)
bond.sort_index(inplace=True)
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
bond.iloc[10]
# Out:
# Year                           1989
# Actor                Timothy Dalton
# Director                  John Glen
# Box Office                    250.9
# Budget                         56.7
# Bond Actor Salary               7.9
# Name: Licence to Kill, dtype: object

# %%
bond.iloc[20:]
# Out:
#                              Year           Actor            Director  \
# Film
# The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me         1977     Roger Moore       Lewis Gilbert
# The World Is Not Enough      1999  Pierce Brosnan       Michael Apted
# Thunderball                  1965    Sean Connery       Terence Young
# Tomorrow Never Dies          1997  Pierce Brosnan  Roger Spottiswoode
# You Only Live Twice          1967    Sean Connery       Lewis Gilbert
#
#                              Box Office  Budget  Bond Actor Salary
# Film
# The Man with the Golden Gun       334.0    27.7                NaN
# The Spy Who Loved Me              533.0    45.1                NaN
# The World Is Not Enough           439.5   158.3               13.5
# Thunderball                       848.1    41.9                4.7
# Tomorrow Never Dies               463.2   133.9               10.0
# ...

# %%
bond.iloc[[10, 15]]
# Out:
#                                  Year           Actor       Director  \
# Film
# Licence to Kill                  1989  Timothy Dalton      John Glen
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Licence to Kill                       250.9    56.7                7.9
# On Her Majesty's Secret Service       291.5    37.3                0.6

# %% [markdown]
# ## The Catch-All .ix[] Method

# %%
# bond.ix["GoldenEye"]  not working

# %%
# bond.ix[20] .ix is deprecated

# %% [markdown]
# ## Second Arguments to .loc[], .iloc[], and .ix[] Methods

# %%
bond.loc["Licence to Kill", "Actor": "Director"] #Sequently
# Out:
# Actor       Timothy Dalton
# Director         John Glen
# Name: Licence to Kill, dtype: object

# %%
bond.loc["Licence to Kill", ["Actor", "Budget", "Year"]] #Sequently
# Out:
# Actor     Timothy Dalton
# Budget              56.7
# Year                1989
# Name: Licence to Kill, dtype: object

# %%
bond.iloc[14, 2]
# Out:
# 'John Glen'

# %%
bond.iloc[14, 2:6]
# Out:
# Director             John Glen
# Box Office               373.8
# Budget                    53.9
# Bond Actor Salary          7.8
# Name: Octopussy, dtype: object

# %%
bond.iloc[14, [2,3,5,1]]
# Out:
# Director               John Glen
# Box Office                 373.8
# Bond Actor Salary            7.8
# Actor                Roger Moore
# Name: Octopussy, dtype: object

# %% [markdown]
# ##  Set New Values for a Specific Cell or Row

# %%
 bond.loc["Dr. No", "Actor"] = "Bilal Hameed"

# %%
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Bilal Hameed       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
bond.loc["From Russia with Love", ["Actor","Director","Box Office","Budget","Bond Actor Salary"]]=["Asfand","Zia","852","555","456"]

# %%
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Bilal Hameed       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963          Asfand                 Zia
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
bond.loc["Dr. No", ["Actor", "Box Office", "Bond Actor Salary"]]=["Bilal", "India", "8.2"]

# %%
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962           Bilal       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963          Asfand                 Zia
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %% [markdown]
# ## Set Multiple Values in DataFrame

# %%
mask=bond["Actor"] == "Sean Connery"
mask
# Out:
# Film
# A View to a Kill                   False
# Casino Royale                      False
# Casino Royale                      False
# Diamonds Are Forever                True
# Die Another Day                    False
# Dr. No                             False
# For Your Eyes Only                 False
# From Russia with Love              False
# GoldenEye                          False
# Goldfinger                          True
# Licence to Kill                    False
# Live and Let Die                   False
# Moonraker                          False
# Never Say Never Again               True
# Octopussy                          False
# On Her Majesty's Secret Service    False
# Quantum of Solace                  False
# Skyfall                            False
# Spectre                            False
# The Living Daylights               False
# The Man with the Golden Gun        False
# The Spy Who Loved Me               False
# The World Is Not Enough            False
# ...

# %%
bond[mask]
# Out:
#                        Year         Actor        Director Box Office Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton      442.5   34.7
# Goldfinger             1964  Sean Connery    Guy Hamilton      820.4   18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner        380     86
# Thunderball            1965  Sean Connery   Terence Young      848.1   41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert      514.2   59.9
#
#                       Bond Actor Salary
# Film
# Diamonds Are Forever                5.8
# Goldfinger                          3.2
# Never Say Never Again               NaN
# Thunderball                         4.7
# You Only Live Twice                 4.4

# %%
bond[mask]["Actor"] = "Sir Sean Connery"
bond
# Out:
# C:\Users\Bilal\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962           Bilal       Terence Young
# ...

# %%
bond[mask]
# Out:
#                        Year         Actor        Director Box Office Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton      442.5   34.7
# Goldfinger             1964  Sean Connery    Guy Hamilton      820.4   18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner        380     86
# Thunderball            1965  Sean Connery   Terence Young      848.1   41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert      514.2   59.9
#
#                       Bond Actor Salary
# Film
# Diamonds Are Forever                5.8
# Goldfinger                          3.2
# Never Say Never Again               NaN
# Thunderball                         4.7
# You Only Live Twice                 4.4

# %%
df2=bond[mask]
df2["Actor"] = "Sir Sean Connery"
df2
# bond
# Out:
# C:\Users\Bilal\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                        Year             Actor        Director Box Office  \
# Film
# Diamonds Are Forever   1971  Sir Sean Connery    Guy Hamilton      442.5
# Goldfinger             1964  Sir Sean Connery    Guy Hamilton      820.4
# Never Say Never Again  1983  Sir Sean Connery  Irvin Kershner        380
# Thunderball            1965  Sir Sean Connery   Terence Young      848.1
# You Only Live Twice    1967  Sir Sean Connery   Lewis Gilbert      514.2
#
#                       Budget Bond Actor Salary
# Film
# Diamonds Are Forever    34.7               5.8
# Goldfinger              18.6               3.2
# ...

# %%
#here its go...

# %%
bond.loc[mask, "Actor"] = "Bilal Hameed"

# %%
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Bilal Hameed        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962           Bilal       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963          Asfand                 Zia
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Bilal Hameed        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
# Back to orignal

# %%
mask1=bond["Actor"]=="Bilal Hameed"
mask1
# Out:
# Film
# A View to a Kill                   False
# Casino Royale                      False
# Casino Royale                      False
# Diamonds Are Forever                True
# Die Another Day                    False
# Dr. No                             False
# For Your Eyes Only                 False
# From Russia with Love              False
# GoldenEye                          False
# Goldfinger                          True
# Licence to Kill                    False
# Live and Let Die                   False
# Moonraker                          False
# Never Say Never Again               True
# Octopussy                          False
# On Her Majesty's Secret Service    False
# Quantum of Solace                  False
# Skyfall                            False
# Spectre                            False
# The Living Daylights               False
# The Man with the Golden Gun        False
# The Spy Who Loved Me               False
# The World Is Not Enough            False
# ...

# %%
bond.loc[mask, "Actor"] = "Sean Connery"

# %%
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962           Bilal       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963          Asfand                 Zia
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %% [markdown]
# ## Rename Index Labels or Columns in a DataFrame

# %%
bond.rename(columns={"Year":"Release Date"}, inplace=True)

# %%
bond
# Out:
#                                  Release Date           Actor  \
# Film
# A View to a Kill                         1985     Roger Moore
# Casino Royale                            2006    Daniel Craig
# Casino Royale                            1967     David Niven
# Diamonds Are Forever                     1971    Sean Connery
# Die Another Day                          2002  Pierce Brosnan
# Dr. No                                   1962           Bilal
# For Your Eyes Only                       1981     Roger Moore
# From Russia with Love                    1963          Asfand
# GoldenEye                                1995  Pierce Brosnan
# Goldfinger                               1964    Sean Connery
# Licence to Kill                          1989  Timothy Dalton
# Live and Let Die                         1973     Roger Moore
# Moonraker                                1979     Roger Moore
# Never Say Never Again                    1983    Sean Connery
# ...

# %%
bond.rename(index={"Dr. No":"Doctor. No", "GoldenEye": "Golden Eye"}, inplace= True)

# %%
bond.columns
# Out:
# Index(['Release Date', 'Actor', 'Director', 'Box Office', 'Budget',
#        'Bond Actor Salary'],
#       dtype='object')

# %%
bond.columns=["A", "B", "C", "D", "E", "F"]

# %%
bond
# Out:
#                                     A               B                   C  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Doctor. No                       1962           Bilal       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963          Asfand                 Zia
# Golden Eye                       1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %% [markdown]
# ## Delete Rows or Columns from a DataFrame

# %%
bond.drop("Thunderball")
# Out:
#                                     A               B                   C  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Doctor. No                       1962           Bilal       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963          Asfand                 Zia
# Golden Eye                       1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
bond.drop(["Skyfall", "Spectre", "The Spy Who Loved Me" ])
# Out:
#                                     A               B                   C  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Doctor. No                       1962           Bilal       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963          Asfand                 Zia
# Golden Eye                       1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
bond.drop("Box Office", axis=1)
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
bond.drop(["Box Office", "Year"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-4292a779b535> in <module>
# ----> 1 bond.drop(["Box Office", "Year"], axis=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
bond.drop(labels=["Box Office", "Year"], axis=1)
# Out:
#                                           Actor            Director  Budget  \
# Film
# A View to a Kill                    Roger Moore           John Glen    54.5
# Casino Royale                      Daniel Craig     Martin Campbell   145.3
# Casino Royale                       David Niven          Ken Hughes    85.0
# Diamonds Are Forever               Sean Connery        Guy Hamilton    34.7
# Die Another Day                  Pierce Brosnan        Lee Tamahori   154.2
# Dr. No                             Sean Connery       Terence Young     7.0
# For Your Eyes Only                  Roger Moore           John Glen    60.2
# From Russia with Love              Sean Connery       Terence Young    12.6
# GoldenEye                        Pierce Brosnan     Martin Campbell    76.9
# Goldfinger                         Sean Connery        Guy Hamilton    18.6
# Licence to Kill                  Timothy Dalton           John Glen    56.7
# ...

# %%
actor=bond.pop("Actor")

# %%
actor
# Out:
# Film
# A View to a Kill                      Roger Moore
# Casino Royale                        Daniel Craig
# Casino Royale                         David Niven
# Diamonds Are Forever                 Sean Connery
# Die Another Day                    Pierce Brosnan
# Dr. No                               Sean Connery
# For Your Eyes Only                    Roger Moore
# From Russia with Love                Sean Connery
# GoldenEye                          Pierce Brosnan
# Goldfinger                           Sean Connery
# Licence to Kill                    Timothy Dalton
# Live and Let Die                      Roger Moore
# Moonraker                             Roger Moore
# Never Say Never Again                Sean Connery
# Octopussy                             Roger Moore
# On Her Majesty's Secret Service    George Lazenby
# Quantum of Solace                    Daniel Craig
# Skyfall                              Daniel Craig
# Spectre                              Daniel Craig
# ...

# %%
del bond["Director"]

# %%
bond.head()
# Out:
#                       Year  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill      1985       275.2    54.5                9.1
# Casino Royale         2006       581.5   145.3                3.3
# Casino Royale         1967       315.0    85.0                NaN
# Diamonds Are Forever  1971       442.5    34.7                5.8
# Die Another Day       2002       465.4   154.2               17.9

# %% [markdown]
# ## Create Random Sample with the .sample() Method

# %%
bond=pd.read_csv("jamesbond.csv")
bond.set_index("Film" , inplace=True)
bond.sort_index(inplace=True)
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
bond.sample(n=5)
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Skyfall                2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Quantum of Solace      2008  Daniel Craig   Marc Forster       514.2   181.4
# Octopussy              1983   Roger Moore      John Glen       373.8    53.9
#
#                        Bond Actor Salary
# Film
# From Russia with Love                1.6
# Skyfall                             14.5
# Thunderball                          4.7
# Quantum of Solace                    8.1
# Octopussy                            7.8

# %%
bond.sample(frac=.25)
# Out:
#                        Year           Actor         Director  Box Office  \
# Film
# Never Say Never Again  1983    Sean Connery   Irvin Kershner       380.0
# Skyfall                2012    Daniel Craig       Sam Mendes       943.5
# GoldenEye              1995  Pierce Brosnan  Martin Campbell       518.5
# From Russia with Love  1963    Sean Connery    Terence Young       543.8
# Octopussy              1983     Roger Moore        John Glen       373.8
# Licence to Kill        1989  Timothy Dalton        John Glen       250.9
#
#                        Budget  Bond Actor Salary
# Film
# Never Say Never Again    86.0                NaN
# Skyfall                 170.2               14.5
# GoldenEye                76.9                5.1
# From Russia with Love    12.6                1.6
# Octopussy                53.9                7.8
# Licence to Kill          56.7                7.9

# %%
bond.sample(n=2, axis=1)
# Out:
#                                            Director  Budget
# Film
# A View to a Kill                          John Glen    54.5
# Casino Royale                       Martin Campbell   145.3
# Casino Royale                            Ken Hughes    85.0
# Diamonds Are Forever                   Guy Hamilton    34.7
# Die Another Day                        Lee Tamahori   154.2
# Dr. No                                Terence Young     7.0
# For Your Eyes Only                        John Glen    60.2
# From Russia with Love                 Terence Young    12.6
# GoldenEye                           Martin Campbell    76.9
# Goldfinger                             Guy Hamilton    18.6
# Licence to Kill                           John Glen    56.7
# Live and Let Die                       Guy Hamilton    30.8
# Moonraker                             Lewis Gilbert    91.5
# Never Say Never Again                Irvin Kershner    86.0
# Octopussy                                 John Glen    53.9
# ...

# %% [markdown]
# ## The .nsmallest() and .nlargest() Methods

# %%
bond.sort_values("Box Office", ascending=False)
# Out:
#                                  Year           Actor            Director  \
# Film
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Thunderball                      1965    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Spectre                          2015    Daniel Craig          Sam Mendes
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# From Russia with Love            1963    Sean Connery       Terence Young
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# ...

# %%
bond.nlargest(3, columns = "Box Office")
# Out:
#              Year         Actor       Director  Box Office  Budget  \
# Film
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#              Bond Actor Salary
# Film
# Skyfall                   14.5
# Thunderball                4.7
# Goldfinger                 3.2

# %%
bond.nsmallest(3, columns = "Box Office")
# Out:
#                                  Year           Actor       Director  \
# Film
# Licence to Kill                  1989  Timothy Dalton      John Glen
# A View to a Kill                 1985     Roger Moore      John Glen
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Licence to Kill                       250.9    56.7                7.9
# A View to a Kill                      275.2    54.5                9.1
# On Her Majesty's Secret Service       291.5    37.3                0.6

# %%
bond.nsmallest(1, "Bond Actor Salary")
# Out:
#         Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No  1962  Sean Connery  Terence Young       448.8     7.0
#
#         Bond Actor Salary
# Film
# Dr. No                0.6

# %%
bond["Box Office"].nsmallest()
# Out:
# Film
# Licence to Kill                    250.9
# A View to a Kill                   275.2
# On Her Majesty's Secret Service    291.5
# The Living Daylights               313.5
# Casino Royale                      315.0
# Name: Box Office, dtype: float64

# %% [markdown]
# ## Filtering with the .where() Method

# %%
mask=bond["Actor"]== "Sean Connery"
bond[mask]
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond Actor Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# ...

# %%
bond.where(mask)
# Out:
#                                    Year         Actor        Director  \
# Film
# A View to a Kill                    NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Diamonds Are Forever             1971.0  Sean Connery    Guy Hamilton
# Die Another Day                     NaN           NaN             NaN
# Dr. No                           1962.0  Sean Connery   Terence Young
# For Your Eyes Only                  NaN           NaN             NaN
# From Russia with Love            1963.0  Sean Connery   Terence Young
# GoldenEye                           NaN           NaN             NaN
# Goldfinger                       1964.0  Sean Connery    Guy Hamilton
# Licence to Kill                     NaN           NaN             NaN
# Live and Let Die                    NaN           NaN             NaN
# ...

# %%
mask1=bond["Box Office"]>800

# %%
bond[mask1]
# Out:
#              Year         Actor       Director  Box Office  Budget  \
# Film
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
#
#              Bond Actor Salary
# Film
# Goldfinger                 3.2
# Skyfall                   14.5
# Thunderball                4.7

# %%
bond.where(mask1)
# Out:
#                                    Year         Actor       Director  \
# Film
# A View to a Kill                    NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Diamonds Are Forever                NaN           NaN            NaN
# Die Another Day                     NaN           NaN            NaN
# Dr. No                              NaN           NaN            NaN
# For Your Eyes Only                  NaN           NaN            NaN
# From Russia with Love               NaN           NaN            NaN
# GoldenEye                           NaN           NaN            NaN
# Goldfinger                       1964.0  Sean Connery   Guy Hamilton
# Licence to Kill                     NaN           NaN            NaN
# Live and Let Die                    NaN           NaN            NaN
# ...

# %%
bond.where(mask1 & mask)
# Out:
#                                    Year         Actor       Director  \
# Film
# A View to a Kill                    NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Diamonds Are Forever                NaN           NaN            NaN
# Die Another Day                     NaN           NaN            NaN
# Dr. No                              NaN           NaN            NaN
# For Your Eyes Only                  NaN           NaN            NaN
# From Russia with Love               NaN           NaN            NaN
# GoldenEye                           NaN           NaN            NaN
# Goldfinger                       1964.0  Sean Connery   Guy Hamilton
# Licence to Kill                     NaN           NaN            NaN
# Live and Let Die                    NaN           NaN            NaN
# ...

# %% [markdown]
# ## The .query() Method

# %%
bond.rename(columns={"Box Office":"Box_Office", "Bond Actor Salary":"Bond_Actor_Salary"}, inplace= True)

# %%
bond.head()
# Out:
#                       Year           Actor         Director  Box_Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond_Actor_Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.columns=[column_name.replace(" ", "_") for column_name in bond.columns]

# %%
bond.query('Actor=="David Niven"')
# Out:
#                Year        Actor    Director  Box_Office  Budget  \
# Film
# Casino Royale  1967  David Niven  Ken Hughes       315.0    85.0
#
#                Bond_Actor_Salary
# Film
# Casino Royale                NaN

# %%
bond.query("Director=='Lee Tamahori'")
# Out:
#                  Year           Actor      Director  Box_Office  Budget  \
# Film
# Die Another Day  2002  Pierce Brosnan  Lee Tamahori       465.4   154.2
#
#                  Bond_Actor_Salary
# Film
# Die Another Day               17.9

# %%
bond.query("Box_Office == '465.4'")
# Out:
#                  Year           Actor      Director  Box_Office  Budget  \
# Film
# Die Another Day  2002  Pierce Brosnan  Lee Tamahori       465.4   154.2
#
#                  Bond_Actor_Salary
# Film
# Die Another Day               17.9

# %%
bond.query("Box_Office > 465.4")
# Out:
#                        Year           Actor         Director  Box_Office  \
# Film
# Casino Royale          2006    Daniel Craig  Martin Campbell       581.5
# From Russia with Love  1963    Sean Connery    Terence Young       543.8
# GoldenEye              1995  Pierce Brosnan  Martin Campbell       518.5
# Goldfinger             1964    Sean Connery     Guy Hamilton       820.4
# Moonraker              1979     Roger Moore    Lewis Gilbert       535.0
# Quantum of Solace      2008    Daniel Craig     Marc Forster       514.2
# Skyfall                2012    Daniel Craig       Sam Mendes       943.5
# Spectre                2015    Daniel Craig       Sam Mendes       726.7
# The Spy Who Loved Me   1977     Roger Moore    Lewis Gilbert       533.0
# Thunderball            1965    Sean Connery    Terence Young       848.1
# You Only Live Twice    1967    Sean Connery    Lewis Gilbert       514.2
#
#                        Budget  Bond_Actor_Salary
# Film
# ...

# %%
bond.query("Actor=='Roger Moore' and Director=='Sam Mendes'")
# Out:
# Empty DataFrame
# Columns: [Year, Actor, Director, Box_Office, Budget, Bond_Actor_Salary]
# Index: []

# %%
bond.query("Actor=='Roger Moore' or Director=='Sam Mendes'")
# Out:
#                              Year         Actor       Director  Box_Office  \
# Film
# A View to a Kill             1985   Roger Moore      John Glen       275.2
# For Your Eyes Only           1981   Roger Moore      John Glen       449.4
# Live and Let Die             1973   Roger Moore   Guy Hamilton       460.3
# Moonraker                    1979   Roger Moore  Lewis Gilbert       535.0
# Octopussy                    1983   Roger Moore      John Glen       373.8
# Skyfall                      2012  Daniel Craig     Sam Mendes       943.5
# Spectre                      2015  Daniel Craig     Sam Mendes       726.7
# The Man with the Golden Gun  1974   Roger Moore   Guy Hamilton       334.0
# The Spy Who Loved Me         1977   Roger Moore  Lewis Gilbert       533.0
#
#                              Budget  Bond_Actor_Salary
# Film
# A View to a Kill               54.5                9.1
# For Your Eyes Only             60.2                NaN
# ...

# %%
bond.query("Actor in ['Roger Moore', 'Daniel Craig']")
# Out:
#                              Year         Actor         Director  Box_Office  \
# Film
# A View to a Kill             1985   Roger Moore        John Glen       275.2
# Casino Royale                2006  Daniel Craig  Martin Campbell       581.5
# For Your Eyes Only           1981   Roger Moore        John Glen       449.4
# Live and Let Die             1973   Roger Moore     Guy Hamilton       460.3
# Moonraker                    1979   Roger Moore    Lewis Gilbert       535.0
# Octopussy                    1983   Roger Moore        John Glen       373.8
# Quantum of Solace            2008  Daniel Craig     Marc Forster       514.2
# Skyfall                      2012  Daniel Craig       Sam Mendes       943.5
# Spectre                      2015  Daniel Craig       Sam Mendes       726.7
# The Man with the Golden Gun  1974   Roger Moore     Guy Hamilton       334.0
# The Spy Who Loved Me         1977   Roger Moore    Lewis Gilbert       533.0
#
# ...

# %%
bond.query("Actor in ['Roger Moore', 'Daniel Craig'] and Director in ['John Glen']")
# Out:
#                     Year        Actor   Director  Box_Office  Budget  \
# Film
# A View to a Kill    1985  Roger Moore  John Glen       275.2    54.5
# For Your Eyes Only  1981  Roger Moore  John Glen       449.4    60.2
# Octopussy           1983  Roger Moore  John Glen       373.8    53.9
#
#                     Bond_Actor_Salary
# Film
# A View to a Kill                  9.1
# For Your Eyes Only                NaN
# Octopussy                         7.8

# %%
bond.query("Actor not in ['Roger Moore', 'Daniel Craig']")
# Out:
#                                  Year           Actor            Director  \
# Film
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# The Living Daylights             1987  Timothy Dalton           John Glen
# The World Is Not Enough          1999  Pierce Brosnan       Michael Apted
# ...

# %%
bond.query("Actor not in ['Roger Moore', 'Daniel Craig'] and Director in ['John Glen']")
# Out:
#                       Year           Actor   Director  Box_Office  Budget  \
# Film
# Licence to Kill       1989  Timothy Dalton  John Glen       250.9    56.7
# The Living Daylights  1987  Timothy Dalton  John Glen       313.5    68.8
#
#                       Bond_Actor_Salary
# Film
# Licence to Kill                     7.9
# The Living Daylights                5.2

# %% [markdown]
# ## A Review of the .apply() Method on Single Columns

# %%
def convert_to_String_and_add_millions(number):
    return str(number)+ " Million!"

# %%
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
bond["Box Office"]
# Out:
# Film
# A View to a Kill                   275.2
# Casino Royale                      581.5
# Casino Royale                      315.0
# Diamonds Are Forever               442.5
# Die Another Day                    465.4
# Dr. No                             448.8
# For Your Eyes Only                 449.4
# From Russia with Love              543.8
# GoldenEye                          518.5
# Goldfinger                         820.4
# Licence to Kill                    250.9
# Live and Let Die                   460.3
# Moonraker                          535.0
# Never Say Never Again              380.0
# Octopussy                          373.8
# On Her Majesty's Secret Service    291.5
# Quantum of Solace                  514.2
# Skyfall                            943.5
# Spectre                            726.7
# The Living Daylights               313.5
# The Man with the Golden Gun        334.0
# The Spy Who Loved Me               533.0
# The World Is Not Enough            439.5
# ...

# %%
bond["Box Office"]=bond["Box Office"].apply(convert_to_String_and_add_millions)

# %%
bond.head()
# Out:
#                       Year           Actor         Director      Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen  275.2 Million!
# Casino Royale         2006    Daniel Craig  Martin Campbell  581.5 Million!
# Casino Royale         1967     David Niven       Ken Hughes  315.0 Million!
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton  442.5 Million!
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori  465.4 Million!
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond["Budget"]=bond["Budget"].apply(convert_to_String_and_add_millions)

# %%
columns=["Box Office", "Budget", "Bond Actor Salary"]
for col in columns:
    bond[col] = bond[col].apply(convert_to_String_and_add_millions)

# %%
bond.head()
# Out:
#                       Year           Actor         Director  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen
# Casino Royale         2006    Daniel Craig  Martin Campbell
# Casino Royale         1967     David Niven       Ken Hughes
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori
#
#                                    Box Office                   Budget  \
# Film
# A View to a Kill      275.2 Million! Million!   54.5 Million! Million!
# Casino Royale         581.5 Million! Million!  145.3 Million! Million!
# Casino Royale         315.0 Million! Million!   85.0 Million! Million!
# Diamonds Are Forever  442.5 Million! Million!   34.7 Million! Million!
# Die Another Day       465.4 Million! Million!  154.2 Million! Million!
#
#                      Bond Actor Salary
# Film
# A View to a Kill          9.1 Million!
# Casino Royale             3.3 Million!
# ...

# %%
bond=pd.read_csv("jamesbond.csv")
bond.set_index("Film" , inplace=True)
bond.sort_index(inplace=True)
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %% [markdown]
# ## The .apply() Method with Row Values

# %%
def good_movie(row):
    actor=row[1]
    budget=row[4]
    if actor=="Pierce Brosnan":
        return "The Best"
    elif actor=="Roger Moore" and budget>40:
        return "Enjoyable"
    else:
        return "I Have No Clue"

# %%
mask1=bond.apply(good_movie, axis=1)

# %%
bond["Ranking"]=mask1

# %%
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %% [markdown]
# ## The .copy() Method

# %%
directors=bond["Director"]

# %%
directors.head(3)
# Out:
# Film
# A View to a Kill          John Glen
# Casino Royale       Martin Campbell
# Casino Royale            Ken Hughes
# Name: Director, dtype: object

# %%
directors["A View to a Kill"]="Mr John Glen"
# Out:
# C:\Users\Bilal\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
directors.head()
# Out:
# Film
# A View to a Kill           Mr John Glen
# Casino Royale           Martin Campbell
# Casino Royale                Ken Hughes
# Diamonds Are Forever       Guy Hamilton
# Die Another Day            Lee Tamahori
# Name: Director, dtype: object

# %%
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore     Mr John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary         Ranking
# Film
# A View to a Kill        54.5                9.1       Enjoyable
# Casino Royale          145.3                3.3  I Have No Clue
# Casino Royale           85.0                NaN  I Have No Clue
# Diamonds Are Forever    34.7                5.8  I Have No Clue
# Die Another Day        154.2               17.9        The Best

# %%
directors=bond["Director"].copy()

# %%
directors
# Out:
# Film
# A View to a Kill                         Mr John Glen
# Casino Royale                         Martin Campbell
# Casino Royale                              Ken Hughes
# Diamonds Are Forever                     Guy Hamilton
# Die Another Day                          Lee Tamahori
# Dr. No                                  Terence Young
# For Your Eyes Only                          John Glen
# From Russia with Love                   Terence Young
# GoldenEye                             Martin Campbell
# Goldfinger                               Guy Hamilton
# Licence to Kill                             John Glen
# Live and Let Die                         Guy Hamilton
# Moonraker                               Lewis Gilbert
# Never Say Never Again                  Irvin Kershner
# Octopussy                                   John Glen
# On Her Majesty's Secret Service         Peter R. Hunt
# Quantum of Solace                        Marc Forster
# ...

# %%
directors["A View to a Kill"]="Mr John Glen"

# %%
directors
# Out:
# Film
# A View to a Kill                         Mr John Glen
# Casino Royale                         Martin Campbell
# Casino Royale                              Ken Hughes
# Diamonds Are Forever                     Guy Hamilton
# Die Another Day                          Lee Tamahori
# Dr. No                                  Terence Young
# For Your Eyes Only                          John Glen
# From Russia with Love                   Terence Young
# GoldenEye                             Martin Campbell
# Goldfinger                               Guy Hamilton
# Licence to Kill                             John Glen
# Live and Let Die                         Guy Hamilton
# Moonraker                               Lewis Gilbert
# Never Say Never Again                  Irvin Kershner
# Octopussy                                   John Glen
# On Her Majesty's Secret Service         Peter R. Hunt
# Quantum of Solace                        Marc Forster
# ...

# %%
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore        Mr John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...
